# %%
# %pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("test_data/titanic.csv")
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 38            39         0       3
# 666          667         0       2
# 509          510         1       3
# 456          457         0       1
# 29            30         0       3
# 185          186         0       1
# 879          880         1       1
# 326          327         0       3
# 643          644         1       3
# 848          849         0       2
#
#                                               Name     Sex   Age  SibSp  \
# 38              Vander Planke, Miss. Augusta Maria  female  18.0      2
# 666                    Butler, Mr. Reginald Fenton    male  25.0      0
# 509                                 Lang, Mr. Fang    male  26.0      0
# 456                      Millet, Mr. Francis Davis    male  65.0      0
# 29                             Todoroff, Mr. Lalio    male   NaN      0
# 185                          Rood, Mr. Hugh Roscoe    male   NaN      0
# ...

# %%
x = np.array([round(np.random.random()*100) for i in range(10)])
print(x)
print(np.quantile(x, .75), np.mean(x), np.median(x))
print(np.std(x), np.var(x))

counts, bins = np.histogram(x)
plt.hist(bins[:-1], bins, weights=counts)
# Out:
# [68 97 19 13 74 19 16 55 27  1]
# 64.75 38.9 23.0
# 30.461286906498216 927.8899999999998
# (array([1., 4., 1., 0., 0., 1., 1., 1., 0., 1.]),
#  array([ 1. , 10.6, 20.2, 29.8, 39.4, 49. , 58.6, 68.2, 77.8, 87.4, 97. ]),
#  <BarContainer object of 10 artists>)
