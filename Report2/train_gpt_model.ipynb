# %%
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from gpt_mini.model import GPT
from gpt_mini.trainer import Trainer
from gpt_mini.bpe import MidiDataset

# %%
# VERSION = os.environ["VERSION"]

# %%
model_config = GPT.get_default_config()
model_config.model_type = 'gpt-nano'
model_config.vocab_size = 65535        # max number of vocabulary
model_config.block_size = 256          # input context length

model = GPT(model_config)
# Out:
# number of parameters: 3.24M

# %%
block_size = 32
# string_from_file = ""
# with open('./output/training.txt', 'r') as inf:
#     string_from_file = inf.read()
# train_dataset = CharDataset(string_from_file, block_size)

train_dataset = MidiDataset(f"./training_data.txt", block_size)
print(train_dataset)

# %%
# your subclass of torch.utils.data.Dataset that emits example
# torch LongTensor of lengths up to 1024, with integers from [0,50257)
train_config = Trainer.get_default_config()
train_config.learning_rate = 0.003  # many possible options, see the file
train_config.max_iters = 2000
train_config.batch_size = 64
train_config.num_workers = 3
trainer = Trainer(train_config, model, train_dataset)
# Out:
# running on device cpu

# %%
def batch_end_callback(trainer):
    if trainer.iter_num % 100 == 0:
        print(f"iter_dt {trainer.iter_dt * 1000:.2f}ms; iter {trainer.iter_num}: train loss {trainer.loss.item():.5f}")

trainer.set_callback('on_batch_end', batch_end_callback)
trainer.run()
# Out:
# tensor([[     53828,   71768755,   71769507,   77601459,   83434035,   89266867,
#            89267621,   95099571,  100932147,  100932771,  106764979,  106765731,
#           112597683,  118364723,  124197555],
#         [     36932,  353898404,  353898403,  353897640,  353898406,  355536806,
#           357175206,  358813606,  360452006,  363728806,  367005617,  367005610,
#           367005604,  368644010,  370282410],
#         [     28228,   28450730,   37431210,   46469034,   51060656,   55517098,
#            55584685,   60043172,   60108713,   64817060,   64817066,   64817075,
#            69083818,   73865126,   73865139],
#         [     28228,   28450730,   37431210,   46469034,   51060656,   55517098,
#            55584685,   60043172,   60108713,   64817060,   64817066,   64817075,
#            69083818,   73865126,   73865139],
#         [     20036,   81664936,   84682280,   87696808,   90711597,   93725894,
# ...
