# %%
# %pip install torch numpy ipywidgets
# Out:
# Requirement already satisfied: torch in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: numpy in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: ipywidgets in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (8.1.6)
# Requirement already satisfied: filelock in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: comm>=0.1.3 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from ipywidgets) (8.31.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from ipywidgets) (3.0.14)
# Requirement already satisfied: decorator in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack_data in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/miniconda3/envs/lab/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # LSTM Example

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

# %%
class SimpleLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(SimpleLSTM, self).__init__()
        self.hidden_size = hidden_size
        # self.num_layers is the number of stacked LSTM layers.
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        # h0 and c0 are the initial hidden state and cell state of the LSTM, respectively.
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        out, _ = self.lstm(x, (h0, c0))
        # out[:, -1, :] selects the output of the last time step in the sequence for each batch.
        out = self.fc(out[:, -1, :])
        return out

# %%
input_size = 1      # Number of features in the input
hidden_size = 50    # Number of features in the hidden state
num_layers = 1      # Number of recurrent layers
output_size = 1     # Number of output features

model = SimpleLSTM(input_size, hidden_size, num_layers, output_size)
criterion = nn.MSELoss()  # Mean Squared Error Loss for regression tasks
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Create dummy data
seq_length = 10
data = np.sin(np.linspace(0, 100, 1000))  # Sine wave data

# Create sequences of data
def create_sequences(data, seq_length):
    xs = []
    ys = []
    for i in range(len(data)-seq_length):
        x = data[i:i+seq_length]
        y = data[i+seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

X, y = create_sequences(data, seq_length)

# Convert to PyTorch tensors
X = torch.from_numpy(X).float().unsqueeze(-1)  # Shape: (num_samples, seq_length, input_size)
y = torch.from_numpy(y).float().unsqueeze(-1)  # Shape: (num_samples, output_size)

plt.plot(data)
plt.show()

# %%
num_epochs = 100

for epoch in range(num_epochs):
    model.train()
    outputs = model(X)
    optimizer.zero_grad()
    loss = criterion(outputs, y)
    loss.backward()
    optimizer.step()

    if (epoch+1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [10/100], Loss: 0.4408
# Epoch [20/100], Loss: 0.3392
# Epoch [30/100], Loss: 0.1915
# Epoch [40/100], Loss: 0.1263
# Epoch [50/100], Loss: 0.1018
# Epoch [60/100], Loss: 0.0834
# Epoch [70/100], Loss: 0.0551
# Epoch [80/100], Loss: 0.0201
# Epoch [90/100], Loss: 0.0055
# Epoch [100/100], Loss: 0.0020

# %%
model.eval()
with torch.no_grad():
    test_seq = torch.from_numpy(data[-seq_length:]).float().unsqueeze(0).unsqueeze(-1)
    prediction = model(test_seq)
    print(f'Prediction: {prediction.item()}')
# Out:
# Prediction: -0.46204525232315063
