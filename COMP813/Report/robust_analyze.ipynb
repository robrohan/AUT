# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
vr_df = pd.read_csv("vit_result_ab.csv")
rn_df = pd.read_csv("resnet8_result_ab.csv")

# %%
display(vr_df.head())
display(rn_df.head())
# Out:
#    Unnamed: 0  corruption  severity    loss_a    loss_b  accuracy_a  \
# 0           0        18.0       1.0  0.661901  0.433177         1.0
# 1           1        18.0       1.0  0.024893  0.502918         1.0
# 2           2        18.0       1.0  0.384312  1.245447         1.0
# 3           3        18.0       1.0  0.381636  0.486834         1.0
# 4           4        18.0       1.0  0.089019  0.050905         1.0
#
#    accuracy_b
# 0         1.0
# 1         1.0
# 2         0.0
# 3         1.0
# 4         1.0
#    Unnamed: 0  corruption  severity    loss_a    loss_b  accuracy_a  \
# 0           0        18.0       1.0  0.241772  0.133853         1.0
# 1           1        18.0       1.0  0.693461  0.727851         1.0
# 2           2        18.0       1.0  0.359320  0.893730         1.0
# 3           3        18.0       1.0  0.001643  0.577411         1.0
# 4           4        18.0       1.0  0.006673  0.465128         1.0
#
#    accuracy_b
# 0         1.0
# 1         0.0
# ...
